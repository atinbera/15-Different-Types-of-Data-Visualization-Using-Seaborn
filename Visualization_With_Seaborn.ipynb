# %%
import seaborn as sns

# %%
data=sns.load_dataset('iris')
data[10:15]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# 13           4.3          3.0           1.1          0.1  setosa
# 14           5.8          4.0           1.2          0.2  setosa

# %%
data['species'].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %% [markdown]
# # 1. Bar Plot

# %%
sns.barplot(x='species',y='petal_length',hue='species',data=data)
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %% [markdown]
# # 2. Scatter Plot

# %%
sns.scatterplot(x='petal_length',y='sepal_length',hue='species',style='species',s=90,data=data)
# Out:
# <Axes: xlabel='petal_length', ylabel='sepal_length'>

# %% [markdown]
# # 3. Histogram

# %%
sns.histplot(x='sepal_length',kde=True,data=data)
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(x='sepal_length',kde=True,hue='species',data=data)
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %% [markdown]
# # 4. Line Plot

# %%
sns.lineplot(x='petal_length',y='petal_width',data=data)
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %% [markdown]
# # 5. Violin Plot

# %%
sns.violinplot(x='species',y='petal_length',data=data,hue='species')
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %% [markdown]
# # 6. Box Plot

# %%
sns.boxplot(x=data['species'],y=data['sepal_length'],data=data,hue=data['species'])
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %% [markdown]
# # 7. Heatmap

# %%
heat_corr=data.corr()
sns.heatmap(heat_corr,annot=True)
# Out:
# <ipython-input-11-6c68b748d5a1>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   heat_corr=data.corr()
# <Axes: >

# %% [markdown]
# # 8. Point Plot

# %%
sns.pointplot(x='species',y='petal_length',data=data,markers ='^',color='g')
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %% [markdown]
# # 9. Density Plot

# %%
sns.kdeplot(x='petal_length',data=data,hue='species',multiple='stack')
# Out:
# <Axes: xlabel='petal_length', ylabel='Density'>

# %%
sns.kdeplot(x='petal_length',y='sepal_length',data=data,hue='species')
# Out:
# <Axes: xlabel='petal_length', ylabel='sepal_length'>

# %% [markdown]
# # 10. Count Plot

# %%
sns.countplot(x='species', data=data)
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %% [markdown]
# # 11. Swarm Plot

# %%
sns.swarmplot(x='sepal_width',y='species',data=data,hue='species',dodge=True,orient='h',size=8)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 6.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='sepal_width', ylabel='species'>

# %% [markdown]
# # 12. Pair Plot

# %%
sns.set(rc = {"figure.figsize":(6,3)})
sns.pairplot(data=data,hue='species',markers=["o", "s", "D"])

# %% [markdown]
# # 13. Facet Grid

# %%
g=sns.FacetGrid(data, col="species", height=4,hue='species')
g.map(sns.histplot, "petal_length")

# %% [markdown]
# # 14. Joint Distribution Plot

# %%
sns.jointplot(x="sepal_length", y="sepal_width", data=data,palette='Set2',hue='species')

# %% [markdown]
# # 15. Cat Plot (Categorical Plot)

# %%
sns.catplot(data=data, x="petal_length", y="species", hue="species",kind="violin", bw=.25, cut=0)

# %%
sns.catplot(data=data, x="petal_length", y="species", kind="violin", color=".9", inner=None)
sns.swarmplot(data=data, x="petal_length", y="species", size=3)
# Out:
# <Axes: xlabel='petal_length', ylabel='species'>
